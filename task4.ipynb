# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Used Car Dataset.csv')
df
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %% [markdown]
# PRE-PROCESSING

# %%
df.isnull()
# Out:
#       Unnamed: 0  car_name  registration_year  insurance_validity  fuel_type  \
# 0          False     False              False               False      False
# 1          False     False              False               False      False
# 2          False     False              False               False      False
# 3          False     False              False               False      False
# 4          False     False              False               False      False
# ...          ...       ...                ...                 ...        ...
# 1548       False     False              False               False      False
# 1549       False     False              False               False      False
# 1550       False     False              False               False      False
# 1551       False     False              False               False      False
# 1552       False     False              False               False      False
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0                                  car_name registration_year  \
# 1548        1548  2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549        1549        2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550        1550                  2017 Honda WR-V i-VTEC S            Jun-17
# 1551        1551  2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552        1552               2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# 1548          Comprehensive    Diesel      5       35000   First Owner
# 1549  Third Party insurance    Petrol      5       10000        999 cc
# 1550          Comprehensive    Petrol      5       49000   First Owner
# 1551          Comprehensive    Petrol      5       40000  Second Owner
# 1552          Comprehensive    Petrol      5       34756   First Owner
#
#      transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('insurance_validity').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('fuel_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.shape
# Out:
# (1553, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1553 non-null   int64
#  1   car_name            1553 non-null   object
#  2   registration_year   1553 non-null   object
#  3   insurance_validity  1553 non-null   object
#  4   fuel_type           1553 non-null   object
#  5   seats               1553 non-null   int64
#  6   kms_driven          1553 non-null   int64
#  7   ownsership          1553 non-null   object
#  8   transmission        1553 non-null   object
#  9   manufacturing_year  1553 non-null   object
#  10  mileage(kmpl)       1550 non-null   float64
#  11  engine(cc)          1550 non-null   float64
#  12  max_power(bhp)      1550 non-null   float64
#  13  torque(Nm)          1549 non-null   float64
#  14  price(in lakhs)     1553 non-null   float64
# ...

# %%
k=df.describe()
k
# Out:
#         Unnamed: 0         seats     kms_driven  mileage(kmpl)    engine(cc)  \
# count  1553.000000   1553.000000    1553.000000    1550.000000  1.550000e+03
# mean    776.000000     91.480361   52841.931101     236.927277  1.471857e+10
# std     448.456798   2403.424060   40067.800347     585.964295  2.185629e+11
# min       0.000000      4.000000     620.000000       7.810000  5.000000e+00
# 25%     388.000000      5.000000   30000.000000      16.342500  1.197000e+03
# 50%     776.000000      5.000000   49134.000000      18.900000  1.462000e+03
# 75%    1164.000000      5.000000   70000.000000      22.000000  1.995000e+03
# max    1552.000000  67000.000000  810000.000000    3996.000000  3.258640e+12
#
#        max_power(bhp)    torque(Nm)  price(in lakhs)
# count    1.550000e+03  1.549000e+03      1553.000000
# mean     1.471857e+10  1.423989e+04       166.141494
# std      2.185629e+11  9.666241e+04      3478.855090
# min      5.000000e+00  5.000000e+00         1.000000
# ...

# %%
k.plot()

# %%
df.info('car_name')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1553 non-null   int64
#  1   car_name            1553 non-null   object
#  2   registration_year   1553 non-null   object
#  3   insurance_validity  1553 non-null   object
#  4   fuel_type           1553 non-null   object
#  5   seats               1553 non-null   int64
#  6   kms_driven          1553 non-null   int64
#  7   ownsership          1553 non-null   object
#  8   transmission        1553 non-null   object
#  9   manufacturing_year  1553 non-null   object
#  10  mileage(kmpl)       1550 non-null   float64
#  11  engine(cc)          1550 non-null   float64
#  12  max_power(bhp)      1550 non-null   float64
#  13  torque(Nm)          1549 non-null   float64
#  14  price(in lakhs)     1553 non-null   float64
# ...

# %%
df.kms_driven.plot()
# Out:
# <Axes: >

# %%
#Finding out unique values
print('car_name',len(df['car_name'].unique()))
print('registration_year', len(df['registration_year'].unique()))
print('insurance_validity', len(df['insurance_validity'].unique()))
print('fuel_type', len(df['fuel_type'].unique()))
print('seats', len(df['seats'].unique()))
print('kms_driven', len(df['kms_driven'].unique()))
print('ownsership', len(df['ownsership'].unique()))
print('transmission', len(df['transmission'].unique()))
print('manufacturing_year', len(df['manufacturing_year'].unique()))
print('mileage(kmpl)', len(df['mileage(kmpl)'].unique()))
print('engine(cc)', len(df['engine(cc)'].unique()))
print('max_power(bhp)', len(df['max_power(bhp)'].unique()))
print('torque(Nm)', len(df['torque(Nm)'].unique()))
print('price(in lakhs)', len(df['price(in lakhs)'].unique()))
# Out:
# car_name 925
# registration_year 178
# insurance_validity 6
# fuel_type 4
# seats 6
# kms_driven 710
# ownsership 22
# transmission 13
# manufacturing_year 19
# mileage(kmpl) 333
# engine(cc) 148
# max_power(bhp) 148
# torque(Nm) 282
# price(in lakhs) 630

# %%
#feature selection correlation
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14,8))
ax=sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-23-c74a9893fc2a>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax=sns.heatmap(df.corr(),annot=True)

# %%
df['company']=df.car_name.str.split(expand=True)[1]
car=df

# %%
import sklearn.preprocessing
label_encoder = sklearn.preprocessing.LabelEncoder()
car['registration_year']=label_encoder.fit_transform(car['registration_year'])
car['insurance_validity'] = label_encoder.fit_transform(car['insurance_validity'])
car['fuel_type'] = label_encoder.fit_transform(car['fuel_type'])
car['seats'] = label_encoder.fit_transform(car['seats'])
car['kms_driven'] = label_encoder.fit_transform(car['kms_driven'])
car['ownsership'] = label_encoder.fit_transform(car['ownsership'])
car['transmission'] = label_encoder.fit_transform(car['transmission'])
car['manufacturing_year'] = label_encoder.fit_transform(car['manufacturing_year'])
car['mileage(kmpl)'] = label_encoder.fit_transform(car['mileage(kmpl)'])
car['engine(cc)'] = label_encoder.fit_transform(car['engine(cc)'])
car['max_power(bhp)'] = label_encoder.fit_transform(car['max_power(bhp)'])
car['torque(Nm)'] = label_encoder.fit_transform(car['torque(Nm)'])
car['price(in lakhs)'] = label_encoder.fit_transform(car['price(in lakhs)'])
car['company'] = label_encoder.fit_transform(car['company'])

# %% [markdown]
# LINEAR REGRESSION

# %%
# !pip install preprocessing
# Out:
# ...
#   Created wheel for nltk: filename=nltk-3.2.4-py3-none-any.whl size=1367706 sha256=c39518331fc861da6bdb590f231cb077facc38852924f9ed517b9666b20b8d61
#   Stored in directory: /root/.cache/pip/wheels/0e/8c/42/bcd0934b61ecf4cef964ccc9881888cca0841ec72266e99de1
# Successfully built nltk
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# ...

# %%
X=car[['insurance_validity', 'fuel_type',
       'kms_driven', 'transmission',
       'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
       'torque(Nm)']]
Y=car[['price(in lakhs)']]

# %%
X.head()
# Out:
#    insurance_validity  fuel_type  kms_driven  transmission  mileage(kmpl)  \
# 0                   0          3         409            10              0
# 1                   0          3         189            10            130
# 2                   0          2         138            10            213
# 3                   0          3          92            11            111
# 4                   0          3         315            10             73
#
#    engine(cc)  max_power(bhp)  torque(Nm)
# 0         100             100          71
# 1          31              31         191
# 2          75              75          50
# 3          45              45         226
# 4          66              66         242

# %%
X.tail()
# Out:
#       insurance_validity  fuel_type  kms_driven  transmission  mileage(kmpl)  \
# 1548                   0          2         227            10            308
# 1549                   4          3          39             8            296
# 1550                   0          3         352            11            134
# 1551                   0          3         261            11            167
# 1552                   0          3         223            11            218
#
#       engine(cc)  max_power(bhp)  torque(Nm)
# 1548         127             127          65
# 1549         116             116          19
# 1550          42              42         107
# 1551          31              31          13
# 1552          40              40         175

# %%
import sklearn.model_selection
x_train,x_test,y_train,y_test =sklearn.model_selection.train_test_split(X,Y,test_size=0.2)

# %%
print("x_train:",x_train.shape)
print("x_test:",x_test.shape)
print("y_train:",y_train.shape)
print("y_test:",y_test.shape)
# Out:
# x_train: (1242, 8)
# x_test: (311, 8)
# y_train: (1242, 1)
# y_test: (311, 1)

# %%
#selection
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %% [markdown]
#  The score of correctly predicted instances to the total number of instances.

# %%
#training
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#evaluation
clf.score(x_test,y_test)
# Out:
# 0.37169707979958144

# %%
predict=clf.predict(x_test)
predict
# Out:
# array([[226.85123163],
#        [382.10573537],
#        [173.91900574],
#        [276.42364181],
#        [478.70438863],
#        [219.27745523],
#        [ 52.26234116],
#        [370.94568225],
#        [620.70243106],
#        [182.42120598],
#        [413.2502021 ],
#        [195.6298972 ],
#        [341.95021356],
#        [175.56177255],
#        [246.64957091],
#        [372.68383382],
#        [325.81801682],
#        [362.01279903],
#        [297.75655884],
#        [315.41205676],
#        [ 16.07306814],
#        [262.85738806],
#        [315.95540087],
#        [380.15064796],
#        [322.61549991],
#        [328.53480851],
#        [387.17321832],
#        [440.44897368],
#        [533.3923889 ],
#        [193.88815634],
#        [328.81830528],
#        [307.50085276],
#        [176.33864113],
#        [128.49656743],
#        [331.69053563],
#        [448.63502574],
#        [210.99215606],
#        [515.70195199],
#        [190.89061189],
#        [278.95574139],
# ...

# %% [markdown]
# *  It quantifies the average squared difference between the predicted values and the actual values in a dataset. The lower the MSE, the better the model is at making predictions.

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
import math
math.sqrt(mean_squared_error(predict,y_test))
# Out:
# 134.72169987339873

# %% [markdown]
# LASSO REGRESSION

# %% [markdown]
# * Used for high dimensional data.

# %%
from sklearn.linear_model import Lasso

# Create a lasso regression model
model = Lasso(alpha=0.2)

# Fit the model to the data
model.fit(x_train,y_train)

# Predict the response for a new data point
y_pred = model.predict(x_test)
y_pred
# Out:
# array([226.98456425, 381.65309168, 174.28171178, 276.68862752,
#        478.23800491, 219.58812247,  52.73403092, 371.0338379 ,
#        620.14355533, 182.70121853, 412.82694044, 195.68900636,
#        341.74691783, 175.91926947, 246.93857121, 372.86160125,
#        326.03257431, 362.15980843, 297.95462402, 315.60234436,
#         16.43404063, 263.04765183, 315.68616354, 379.86070408,
#        322.79632587, 328.69635283, 387.34682404, 440.67328187,
#        533.3898743 , 194.2282376 , 328.47866503, 307.12654734,
#        175.97225403, 128.81948353, 331.9645646 , 448.97947422,
#        211.31298185, 515.24499736, 191.23783625, 278.53777501,
#        358.78343464, 537.2181474 , 376.31456155, 408.90277496,
#        241.84298429, 276.36580304, 559.13014219, 206.44457102,
#        455.77664094, 326.26170296, 339.51503232, 573.37015133,
#        517.85131502, 323.84255653, 199.85368302, 263.09327296,
#        191.27106778, 458.81465489, 118.46631358, 310.07337304,
# ...

# %%
model.score(x_test,y_test)
# Out:
# 0.37199019563794333

# %% [markdown]
# RIDGE REGRESSION

# %% [markdown]
# * It prevents overfitting

# %%
from sklearn.linear_model import Ridge

# Create a lasso regression model
modell = Ridge(alpha=0.2)

# Fit the model to the data
modell.fit(x_train,y_train)

# Predict the response for a new data point
y_pred = modell.predict(x_test)
y_pred
# Out:
# array([[226.87039118],
#        [382.0632095 ],
#        [173.93950479],
#        [276.43551847],
#        [478.66834801],
#        [219.29430293],
#        [ 52.29011254],
#        [370.94917415],
#        [620.65836843],
#        [182.4490158 ],
#        [413.21412966],
#        [195.64328697],
#        [341.96282341],
#        [175.581427  ],
#        [246.66406157],
#        [372.68994432],
#        [325.83063164],
#        [362.02129655],
#        [297.77835241],
#        [315.42385163],
#        [ 16.09228544],
#        [262.87038249],
#        [315.92884235],
#        [380.12764346],
#        [322.62550873],
#        [328.56048204],
#        [387.18312814],
#        [440.46505593],
#        [533.40755931],
#        [193.90591321],
#        [328.78985117],
#        [307.46540351],
#        [176.30266753],
#        [128.51155327],
#        [331.70455747],
#        [448.65882462],
#        [211.009106  ],
#        [515.66621592],
#        [190.90917867],
#        [278.92815847],
# ...

# %%
modell.score(x_test,y_test)
# Out:
# 0.37170515200940357
